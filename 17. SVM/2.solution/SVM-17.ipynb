# %%
import pandas as pd
#load the dataset
df = pd.read_csv('/content/mushroom.csv')

# %%
# Display the first few rows and basic info
print(df.head())
print(df.info())
# Out:
#    Unnamed: 0 cap_shape cap_surface cap_color bruises   odor gill_attachment  \
# 0        1167    sunken       scaly     white      no  anise      descending
# 1        1037    sunken     fibrous       red      no  anise         notched
# 2         309      flat     grooves    purple     yes   foul      descending
# 3         282      bell       scaly      pink     yes  fishy         notched
# 4         820      flat      smooth    yellow     yes  musty            free
#
#   gill_spacing gill_size gill_color  ...  veil_type veil_color ring_number  \
# 0      distant     broad       pink  ...    partial      brown         two
# 1      crowded    narrow  chocolate  ...  universal      brown         two
# 2      crowded     broad     purple  ...  universal     yellow         two
# 3        close     broad     orange  ...    partial     yellow         two
# 4      crowded    narrow     orange  ...  universal      white        none
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot histograms for numeric features
df.hist(figsize=(15, 10))
plt.show()

# %%
 #Box plots for a selected feature
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.show()

# %%
import pandas as pd
import numpy as np

# Assuming 'df' is your DataFrame
# Select only numerical features for correlation
numerical_features = df.select_dtypes(include=np.number).columns
correlation_matrix = df[numerical_features].corr()

# Plot heatmap
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.show()

# %%
# Encode categorical variables using one-hot encoding
df_encoded = pd.get_dummies(df, drop_first=True)

# %%
# Pair plots for selected features
# Assuming 'class_e' was a categorical column and got one-hot encoded
# Check the columns of df_encoded for the transformed column names

print(df_encoded.columns) # Print all columns to identify the correct name

# Replace 'class_e_value' with the actual encoded column name
# For instance, if the original 'class_e' column had values 'A', 'B', 'C',
# the encoded columns might be named 'class_e_A', 'class_e_B', 'class_e_C'
sns.pairplot # Replace 'class_e_value' with the correct encoded column name if found
plt.show()
# Out:
# Index(['Unnamed: 0', 'stalk_height', 'cap_diameter', 'cap_shape_conical',
#        'cap_shape_convex', 'cap_shape_flat', 'cap_shape_sunken',
#        'cap_surface_grooves', 'cap_surface_scaly', 'cap_surface_smooth',
#        ...
#        'population_scattered', 'population_several', 'population_solitary',
#        'habitat_leaves', 'habitat_meadows', 'habitat_paths', 'habitat_urban',
#        'habitat_waste', 'habitat_woods', 'class_poisonous'],
#       dtype='object', length=106)

# %%
sns.countplot(x='class', data=df)
plt.title('Class Distribution')
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
# Define features and target
# Assuming 'class_e' was a categorical column and got one-hot encoded
# Check the columns of df_encoded for the transformed column names
#print(df_encoded.columns) # Uncomment this line to see the available columns

# Find columns related to the original 'class_e' column
class_e_cols = [col for col in df_encoded.columns if col.startswith('class_e_')]

# Drop the encoded 'class_e' columns from features
X = df_encoded.drop(columns=class_e_cols, axis=1)

# Select the encoded 'class_e' columns as the target
y = df_encoded[class_e_cols] # Assuming 'class_e' is your target column; Adjust if necessary

# %%
# Initialize the SVM classifier
model = SVC(kernel='rbf')  # You can choose 'linear', 'poly', 'sigmoid', or 'rbf'

# Train the model
model.fit
# Out:
# <bound method BaseLibSVM.fit of SVC()>

# %%
model.fit
# Out:
# <bound method BaseLibSVM.fit of SVC()>
